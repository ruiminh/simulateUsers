# %%
import ollama

ollama.list()
# Out:
# ListResponse(models=[Model(model='llama3.2:latest', modified_at=datetime.datetime(2024, 10, 23, 11, 5, 46, 364471, tzinfo=TzInfo(7200)), digest='a80c4f17acd55265feec403c7aef86be0c25983ab279d83f3bcd3abbcb5b8b72', size=2019393189, details=ModelDetails(parent_model='', format='gguf', family='llama', families=['llama'], parameter_size='3.2B', quantization_level='Q4_K_M'))])

# %%
models = ollama.list()

for model in models.models:

    print(model.model)
# Out:
# llama3.2:latest
