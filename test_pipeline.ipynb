# %%
import ollama

ollama.list()
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# Cell In[1], line 3
#       1 import ollama
#       2
# ----> 3 ollama.list()
#
# File ~/opt/anaconda3/envs/amai/lib/python3.11/site-packages/ollama/_client.py:626, in Client.list(self)
#     625 def list(self) -> ListResponse:
# --> 626   return self._request(
#     627     ListResponse,
#     628     'GET',
#     629     '/api/tags',
#     630   )
#
# File ~/opt/anaconda3/envs/amai/lib/python3.11/site-packages/ollama/_client.py:199, in Client._request(self, cls, stream, *args, **kwargs)
#     195         yield cls(**part)
#     197   return inner()
# --> 199 return cls(**self._request_raw(*args, **kwargs).json())
#
# File ~/opt/anaconda3/envs/amai/lib/python3.11/site-packages/ollama/_client.py:145, in Client._request_raw(self, *args, **kwargs)
#     143   raise ResponseError(e.response.text, e.response.status_code) from None
# ...
